# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
train = pd.read_csv('titanic/train.csv')
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test = pd.read_csv('titanic/test.csv')
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
target = pd.read_csv('titanic/gender_submission.csv')
target
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
test['Survived'] = target['Survived']
test.shape
# Out:
# (418, 12)

# %%
train_shape = train.shape
train_shape
# Out:
# (891, 12)

# %%
train = train.append(test, ignore_index=True)
train
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ...           ...       ...     ...
# 1304         1305         0       3
# 1305         1306         1       1
# 1306         1307         0       3
# 1307         1308         0       3
# 1308         1309         0       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
train.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.020370 -0.038354  0.028814 -0.055224  0.008942
# Survived       -0.020370  1.000000 -0.264710 -0.053695  0.002370  0.108919
# Pclass         -0.038354 -0.264710  1.000000 -0.408106  0.060832  0.018322
# Age             0.028814 -0.053695 -0.408106  1.000000 -0.243699 -0.150917
# SibSp          -0.055224  0.002370  0.060832 -0.243699  1.000000  0.373587
# Parch           0.008942  0.108919  0.018322 -0.150917  0.373587  1.000000
# Fare            0.031428  0.233622 -0.558629  0.178740  0.160238  0.221539
#
#                  Fare
# PassengerId  0.031428
# Survived     0.233622
# Pclass      -0.558629
# Age          0.178740
# SibSp        0.160238
# Parch        0.221539
# Fare         1.000000

# %%
train.drop(columns=['PassengerId', 'Cabin', 'Ticket'], inplace = True)
train
# Out:
#       Survived  Pclass                                               Name  \
# 0            0       3                            Braund, Mr. Owen Harris
# 1            1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            1       3                             Heikkinen, Miss. Laina
# 3            1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            0       3                           Allen, Mr. William Henry
# ...        ...     ...                                                ...
# 1304         0       3                                 Spector, Mr. Woolf
# 1305         1       1                       Oliva y Ocana, Dona. Fermina
# 1306         0       3                       Saether, Mr. Simon Sivertsen
# 1307         0       3                                Ware, Mr. Frederick
# 1308         0       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch      Fare Embarked
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  1309 non-null   int64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Fare      1308 non-null   float64
#  8   Embarked  1307 non-null   object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 92.2+ KB

# %%
train.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
train_2 = train.copy()

# %%
train.drop(columns=['Name'], inplace=True)
train
# Out:
#       Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0            0       3    male  22.0      1      0    7.2500        S
# 1            1       1  female  38.0      1      0   71.2833        C
# 2            1       3  female  26.0      0      0    7.9250        S
# 3            1       1  female  35.0      1      0   53.1000        S
# 4            0       3    male  35.0      0      0    8.0500        S
# ...        ...     ...     ...   ...    ...    ...       ...      ...
# 1304         0       3    male   NaN      0      0    8.0500        S
# 1305         1       1  female  39.0      0      0  108.9000        C
# 1306         0       3    male  38.5      0      0    7.2500        S
# 1307         0       3    male   NaN      0      0    8.0500        S
# 1308         0       3    male   NaN      1      1   22.3583        C
#
# [1309 rows x 8 columns]

# %%
train['Sex'] = train['Sex'].replace({'female':0, 'male':1})
train
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0            0       3    1  22.0      1      0    7.2500        S
# 1            1       1    0  38.0      1      0   71.2833        C
# 2            1       3    0  26.0      0      0    7.9250        S
# 3            1       1    0  35.0      1      0   53.1000        S
# 4            0       3    1  35.0      0      0    8.0500        S
# ...        ...     ...  ...   ...    ...    ...       ...      ...
# 1304         0       3    1   NaN      0      0    8.0500        S
# 1305         1       1    0  39.0      0      0  108.9000        C
# 1306         0       3    1  38.5      0      0    7.2500        S
# 1307         0       3    1   NaN      0      0    8.0500        S
# 1308         0       3    1   NaN      1      1   22.3583        C
#
# [1309 rows x 8 columns]

# %%
train
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0            0       3    1  22.0      1      0    7.2500        S
# 1            1       1    0  38.0      1      0   71.2833        C
# 2            1       3    0  26.0      0      0    7.9250        S
# 3            1       1    0  35.0      1      0   53.1000        S
# 4            0       3    1  35.0      0      0    8.0500        S
# ...        ...     ...  ...   ...    ...    ...       ...      ...
# 1304         0       3    1   NaN      0      0    8.0500        S
# 1305         1       1    0  39.0      0      0  108.9000        C
# 1306         0       3    1  38.5      0      0    7.2500        S
# 1307         0       3    1   NaN      0      0    8.0500        S
# 1308         0       3    1   NaN      1      1   22.3583        C
#
# [1309 rows x 8 columns]

# %%
train.Sex.value_counts()
# Out:
# 1    843
# 0    466
# Name: Sex, dtype: int64

# %%
# encoder2 = LabelEncoder()
# train.Embarked =  encoder2.fit_transform(train.Embarked)

# %%
train[train.Embarked.isnull()]

# %%
train[train.Fare.isnull()]

# %%
train_rest = train.loc[~train.Embarked.isnull() & ~train.Age.isnull() & ~train.Fare.isnull()]
train_rest.reset_index(inplace=True)
train_rest

# %%
train_rest['Embarked'] =  train_rest['Embarked'].replace({'C':0, 'Q':1, 'S':2})
# train_rest['Sex'] =  encoder.fit_transform(train_rest['Sex'])
# print(utils.multiclass.type_of_target(train_rest['Embarked'].astype('int')))
# print(utils.multiclass.type_of_target(train_rest['Sex'].astype('int')))
# train_rest.Embarked.value_counts()

# %%
train_rest.info()

# %%
from sklearn.model_selection import train_test_split

X = train_rest[['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Parch', 'Fare', 'Embarked']]
y = train_rest[['Age']]

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 16)

# %%
y_test.info()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
age_model = LogisticRegression()
age_model.fit(X_train, y_train)
print(accuracy_score(age_model.predict(X_test), y_test))
