# %%
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv('datasets/data.csv')
dataframe
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
dataframe.isnull().values.any()
# Out:
# True

# %%
dataframe.isnull().sum().sum()
# Out:
# 5

# %%
for column in dataframe.columns:
    print(column, end=' - ')
    print(dataframe[column].isnull().values.any(), end=': ')
    print(dataframe[column].isnull().sum())
    print('\n')
# Out:
# CRIM - False: 0
#
#
# ZN - False: 0
#
#
# INDUS - False: 0
#
#
# CHAS - False: 0
#
#
# NOX - False: 0
#
#
# RM - True: 5
#
#
# AGE - False: 0
#
#
# DIS - False: 0
#
#
# RAD - False: 0
#
#
# TAX - False: 0
#
#
# PTRATIO - False: 0
#
#
# B - False: 0
#
#
# LSTAT - False: 0
#
#
# MEDV - False: 0

# %%
dataframe.dropna(inplace=True)
dataframe
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 506  0.98765   0.0  12.50     0  0.561  6.980  89.0  2.0980    3  320
# 507  0.23456   0.0  12.50     0  0.561  6.980  76.0  2.6540    3  320
# 508  0.44433   0.0  12.50     0  0.561  6.123  98.0  2.9870    3  320
# 509  0.77763   0.0  12.70     0  0.561  6.222  34.0  2.5430    3  329
# 510  0.65432   0.0  12.80     0  0.561  6.760  67.0  2.9870    3  345
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
dataframe.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.617404   11.289526   11.174842    0.069170    0.555209    6.287589
# std      8.600123   23.325350    6.824592    0.253994    0.115611    0.703802
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082268    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.266005    0.000000    9.690000    0.000000    0.538000    6.209000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.629750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.555731    3.775231    9.531621  408.330040   18.498419  356.228379
# ...

# %%
x = dataframe[dataframe.columns[:-1]].values
y = dataframe[dataframe.columns[-1]].values

x_train = x[:406].copy()
x_test = x[406:].copy()

y_train = y[:406].copy()
y_test = y[406:].copy()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# -0.9309617207013292

# %%
normal = dataframe.copy()

# %%
normal['ZN'] = (normal['ZN']-normal['ZN'].min())/(normal['ZN'].max()-normal['ZN'].min())
normal['ZN'].describe()
# Out:
# count    506.000000
# mean       0.112895
# std        0.233253
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.125000
# max        1.000000
# Name: ZN, dtype: float64

# %%
normal['CRIM'] = (normal['CRIM'])/(100)
normal['CRIM'].describe()
# Out:
# count    506.000000
# mean       0.036174
# std        0.086001
# min        0.000063
# 25%        0.000823
# 50%        0.002660
# 75%        0.036771
# max        0.889762
# Name: CRIM, dtype: float64

# %%
model2 = LinearRegression()

# %%
x = normal[normal.columns[:-1]].values
y = normal[normal.columns[-1]].values

x_train = x[:406].copy()
x_test = x[406:].copy()

y_train = y[:406].copy()
y_test = y[406:].copy()

# %%
model2.fit(x_train, y_train)
model2.score(x_test, y_test)
# Out:
# -0.9309617207013332

# %%
normal['RM'] = (normal['RM'])/(10)
normal['RM'].describe()
# Out:
# count    506.000000
# mean       0.006288
# std        0.000704
# min        0.003561
# 25%        0.005886
# 50%        0.006209
# 75%        0.006630
# max        0.008780
# Name: RM, dtype: float64

# %%
normal['AGE'] = (normal['AGE'])/(100)
normal['AGE'].describe()
# Out:
# count    506.000000
# mean       0.006856
# std        0.002816
# min        0.000290
# 25%        0.004503
# 50%        0.007750
# 75%        0.009397
# max        0.010000
# Name: AGE, dtype: float64

# %%
normal['TAX'] = (normal['TAX'])/(1000)
normal['TAX'].describe()
# Out:
# count    506.000000
# mean       0.000408
# std        0.000168
# min        0.000187
# 25%        0.000280
# 50%        0.000330
# 75%        0.000666
# max        0.000711
# Name: TAX, dtype: float64

# %%
normal['B'] = (normal['B'])/(500)
normal['B'].describe()
# Out:
# count    506.000000
# mean       0.001425
# std        0.000365
# min        0.000001
# 25%        0.001499
# 50%        0.001565
# 75%        0.001585
# max        0.001588
# Name: B, dtype: float64

# %%
normal['LSTAT'] = (normal['LSTAT'])/(100)
normal['LSTAT'].describe()
# Out:
# count    506.000000
# mean       0.001287
# std        0.000782
# min        0.000173
# 25%        0.000695
# 50%        0.001146
# 75%        0.001711
# max        0.007600
# Name: LSTAT, dtype: float64

# %%
normal['PTRATIO'] = (normal['PTRATIO'])/(100)
normal['PTRATIO'].describe()
# Out:
# count    506.00000
# mean       0.00185
# std        0.00022
# min        0.00126
# 25%        0.00174
# 50%        0.00191
# 75%        0.00202
# max        0.00230
# Name: PTRATIO, dtype: float64

# %%
normal.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.036174    0.112895    0.372495    0.069170    0.555209    0.006288
# std      0.086001    0.233253    0.227486    0.253994    0.115611    0.000704
# min      0.000063    0.000000    0.015333    0.000000    0.385000    0.003561
# 25%      0.000823    0.000000    0.173000    0.000000    0.449000    0.005886
# 50%      0.002660    0.000000    0.323000    0.000000    0.538000    0.006209
# 75%      0.036771    0.125000    0.603333    0.000000    0.624000    0.006630
# max      0.889762    1.000000    0.924667    1.000000    0.871000    0.008780
#
#               AGE         DIS         RAD         TAX    PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.00000  506.000000
# mean     0.006856    0.251682    0.317721    0.000408    0.00185    0.001425
# ...

# %%
normal['RAD'] = (normal['RAD'])/(30)
normal['RAD'].describe()
# Out:
# count    506.000000
# mean       0.010591
# std        0.009685
# min        0.001111
# 25%        0.004444
# 50%        0.005556
# 75%        0.026667
# max        0.026667
# Name: RAD, dtype: float64

# %%
normal['DIS'] = (normal['DIS'])/(15)
normal['DIS'].describe()
# Out:
# count    506.000000
# mean       0.016779
# std        0.009316
# min        0.005020
# 25%        0.009327
# 50%        0.013876
# 75%        0.022745
# max        0.053896
# Name: DIS, dtype: float64

# %%
normal['INDUS'] = (normal['INDUS'])/(30)
normal['INDUS'].describe()
# Out:
# count    506.000000
# mean       0.012416
# std        0.007583
# min        0.000511
# 25%        0.005767
# 50%        0.010767
# 75%        0.020111
# max        0.030822
# Name: INDUS, dtype: float64

# %%
normal.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.036174    0.112895    0.012416    0.069170    0.555209    0.006288
# std      0.086001    0.233253    0.007583    0.253994    0.115611    0.000704
# min      0.000063    0.000000    0.000511    0.000000    0.385000    0.003561
# 25%      0.000823    0.000000    0.005767    0.000000    0.449000    0.005886
# 50%      0.002660    0.000000    0.010767    0.000000    0.538000    0.006209
# 75%      0.036771    0.125000    0.020111    0.000000    0.624000    0.006630
# max      0.889762    1.000000    0.030822    1.000000    0.871000    0.008780
#
#               AGE         DIS         RAD         TAX    PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.00000  506.000000
# mean     0.006856    0.016779    0.010591    0.000408    0.00185    0.001425
# ...

# %%
model2.fit(x_train, y_train)
model2.score(x_test, y_test)
# Out:
# -0.9309617207013332
