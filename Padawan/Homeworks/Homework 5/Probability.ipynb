# %% [markdown]
# # Probability

# %% [markdown]
# This is a notebook with exercises where you will find some tasks to put in practice your knowledge

# %% [markdown]
# Every Task has underneath a hidden cell with tests, no need to open it, just run all the code as you usually do (shift + enter) and if the solutions are correct you will get and "all tests passed succesfully"

# %% [markdown]
# ## Also we have to install some libraries before we can work on these tasks

# %%
pip install scipy seaborn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 1. Simple probability

# %% [markdown]
# ![Group 3294.png](attachment:e9ef9da2-ad33-48bc-96b4-4a588ccbb448.png)

# %% [markdown]
# First Task will be an easy one, just to understand you know basic probability, in this jar we have 38 candies, where we have 16 red, 9 blue, 8 yellow and 5 green ones, answer the following questions.

# %% [markdown]
# ## NOTE: write probabilities of just integer, floats, fractions, or multiplications (example: 0, 0.5, 4/78, 1/3 * 2/3)

# %%
# What is the probability of extracting a red candy out of the jar?
red_prob = 16/38

# What is the probability of extracting a green candy out of the jar?
green_prob = 5/38

# What is the probability of extracting a candy out of the jar?
candy_prob = 1

# What is the probability of extracting a million dollars out of jar?
rich_bitch_prob = 0

# What is the probability of extracting a blue or yellow candy out of the jar?
blue_yellow_prob = (9+8)/38

# %%
assert red_prob == 16/38, 'wrong red_prob'
assert green_prob == 5/38, 'wrong green_prob'
assert candy_prob == 1, 'wrong candy_prob'
assert rich_bitch_prob == 0, 'wrong rich_bitch_prob'
assert blue_yellow_prob == 17/38, 'wrong green_yellow_prob'
print('all tests passed succesfully')
# Out:
# all tests passed succesfully

# %% [markdown]
# ## Task 2. Addition rule

# %% [markdown]
# ![Group 3294 (1).png](attachment:3cc2aa74-603a-49a8-b550-0f45a4ccfe88.png)

# %% [markdown]
# ![image.png](attachment:cf222451-0189-4099-9088-51b83165f6ce.png)

# %% [markdown]
# Imagine having a deck of 52 card, and you take the top card from the deck, try and calculate next probabilities.

# %%
# What is the probability of getting an ace?
ace_prob = 4/52

# What is the probability of getting a spades?
spades_prob = 13/52

# What is the probability of getting an ace of spades?
ace_and_spades_prob = 1/52

# What is the probability of getting an ace or a spades?
ace_or_spades_prob = 13/52 + 4/52 - 1/52

# %%
assert ace_prob == 4/52, 'wrong ace_prob'
assert spades_prob == 13/52, 'wrong spades_prob'
assert ace_and_spades_prob == 1/52, 'wrong ace_and_spades_prob'
assert ace_or_spades_prob == 16/52, 'wrong ace_or_spades_prob'
print('all tests passed succesfully')
# Out:
# all tests passed succesfully

# %% [markdown]
# ## Task 3. Multiplication rule

# %% [markdown]
# If the two actions are independent from one another, for example as the probability of rain and winning in monopoly

# %% [markdown]
# ![Group 3294 (2).png](attachment:98017634-e435-416b-ad9f-f2ca22f9b251.png)

# %% [markdown]
# Given the same deck of 52 cards, calculate next probabilities.

# %%
# What is the probability of extracting two aces in a row? (withouth putting the first card back in the deck)
two_aces_prob = 4/52 *3/51

# What is the probability of extracting two hearts in a row? (withouth putting the first card back in the deck)
two_hearts_prob = 13/52 * 12/51

# %%
assert two_aces_prob == (4/52 * 3/51), 'wrong two_aces_prob'
assert two_hearts_prob == (13/52 * 12/51), 'wrong two_hearts_prob'
print('all tests passed succesfully')
# Out:
# all tests passed succesfully

# %% [markdown]
# ## Task 4. Conditional probability

# %% [markdown]
# ![image.png](attachment:ec4748c3-68ce-429b-b224-d899e9bc37d4.png)

# %% [markdown]
# Imagine a situation where you have a new disease in town, and you already have some cases of people having this disease, calculate the following probabilities.

# %% [markdown]
# ![Group 3295.png](attachment:5c174e04-b689-4003-8518-1a4506d2ebe6.png)

# %%
# What is the probability of getting this disease?
disease_prob = 109/200

# What is the probability of getting this disease given you are a female?
disease_female_prob = 35/100

# What is the probability of getting this disease giben you are a male?
disease_male_prob = 74/100

# What is the probability of a person being a Male if you know that the person is sick of this disease?
disease_person_male_prob = 74/109

# What is the probability of a person being a Female if you know that the person is not sick of this disease?
no_disease_person_female_prob = 65/91

# %%
assert disease_prob == 109/200, 'wrong disease_prob'
assert disease_female_prob == 35/100, 'wrong disease_female_prob'
assert disease_male_prob == 74/100, 'wrong disease_male_prob'
assert disease_person_male_prob ==  74/109, 'wrong disease_person_male_prob'
assert no_disease_person_female_prob == 65/91, 'wrong no_disease_person_female_prob'
print('all tests passed succesfully')
# Out:
# all tests passed succesfully

# %% [markdown]
# ## Task 5. Random variable

# %% [markdown]
# A random variable is just a variable that extracts numbers out of a distribution randomly

# %%
# X - random variable
import random
X = random.randint(1,30)
X
# Out:
# 15

# %% [markdown]
# The random variable presented here is a __discrete__ random variable, because it has a finite number of value that can be extracted

# %% [markdown]
# ## Task 6. Mean, Variance, Standard deviation

# %% [markdown]
# ![image.png](attachment:56ccc2b8-7831-431b-ab28-26a6ffefa623.png)

# %% [markdown]
# ## Task 7. Continuous Random Variable

# %% [markdown]
# A continuous random variable is a variable that has no limits, that has infinite number of options to be extracted, as we now that between -∞ and ∞ there are infinite numbers, same is for numbers between 0 and 1, there are infinite possible numbers.

# %%
import numpy
X = numpy.random.uniform()
X
# Out:
# 0.3743558338872991

# %% [markdown]
# ## Task 8. Random variable distribution

# %% [markdown]
# Here you can see a random variable that has a bell-shape distribution so called normal distribution, may be you remember from numpy homework.

# %%
import seaborn as sns
from scipy.stats import norm
# generate random numbers from N(0,1) mean 0, standard deviatoin 1
data_normal = norm.rvs(size=10000,loc=0,scale=1)

ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# /home/refjs/.local/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# ## Task 9. Naive Bayes

# %% [markdown]
# In statistics and probability theory, the Bayes’ theorem (also known as the Bayes’ rule) is a mathematical formula used to determine the conditional probability of events. Essentially, the Bayes’ theorem describes the probability of an event based on prior knowledge of the conditions that might be relevant to the event.

# %% [markdown]
# ![image.png](attachment:832b849a-b43d-4fcd-8925-128e979120b9.png)

# %% [markdown]
# * A could mean the event “Patient has liver disease.” Past data tells you that 10% of patients entering your clinic have liver disease. P(A) = 0.10. <br />
# * B could mean that “Patient is an alcoholic.” Five percent of the clinic’s patients are alcoholics. P(B) = 0.05. <br />
# * You might also know that among those patients diagnosed with liver disease, 7% are alcoholics. This is your B|A: the probability that a patient is alcoholic, given that they have liver disease, is 7%.  <br />
# Bayes’ theorem tells you:  <br />
# P(A|B) = (0.07 * 0.1)/0.05 = 0.14 <br />
# In other words, if the patient is an alcoholic, their chances of having liver disease is 0.14 (14%). This is a large increase from the 10% suggested by past data. But it’s still unlikely that any particular patient has liver disease.

# %% [markdown]
# ## Task 10. Naive Bayes in real Task

# %% [markdown]
# Now it's time for real work, go and find the Naive Bayes on the internet and see how it works, also, try apply it on a classification task that you did before if you didn't already.

# %% [markdown]
# ### Well Done! Congrats!
